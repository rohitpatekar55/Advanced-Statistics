# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Problem 1
# ## A physiotherapist with a male football team is interested in studying the relationship between foot injuries and the positions at which the players play from the data collected. Answer the following questions.

# %% [markdown]
# ### 1.1 What is the probability that a randomly chosen player would suffer an injury?

# %%
# Total number of Injured players (x)
# Total number of players (y) 
# Probability that a randomly choosen player would suffer an injury (p)
x = 145
y = 235
p = x/y
print('Probability that a randomly choosen player would suffer an injury is',p)
# Out:
# Probability that a randomly choosen player would suffer an injury is 0.6170212765957447

# %% [markdown]
# ### 1.2 What is the probability that a player is a forward or a winger?

# %%
# Total number of Forward players (x) 
# Total number of Winger (y) 
# Total number of players (z) 
# probability that a player is a forward or a winger (p) 
x = 94
y = 29
z = 235
p = (x+y)/z
print('probability that a player is a forward or a winger is',p)
# Out:
# probability that a player is a forward or a winger is 0.5234042553191489

# %% [markdown]
# ### 1.3 What is the probability that a randomly chosen player plays in a striker position and has a foot injury?

# %%
# Total number of Injured Strikers (x) 
# Total number of players (y) 
# probability that a randomly chosen player plays in a striker position and has a foot injury (p) 
x = 45
y = 235
p = x/y
print('probability that a randomly chosen player plays in a striker position and has a foot injury is',p)
# Out:
# probability that a randomly chosen player plays in a striker position and has a foot injury is 0.19148936170212766

# %% [markdown]
# ### 1.4 What is the probability that a randomly chosen injured player is a striker?

# %%
# Total number of Injured Strikers (x) 
# Total number of Injured players (y)
# the probability that a randomly chosen injured player is a striker (p) 
x = 45
y = 145
p = x/y
print('the probability that a randomly chosen injured player is a striker is',p)
# Out:
# the probability that a randomly chosen injured player is a striker is 0.3103448275862069

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information; (Provide an appropriate visual representation of your answers, without which marks will be deducted)

# %% [markdown]
# ### 2.1 What proportion of the gunny bags have a breaking strength of less than 3.17 kg per sq cm?

# %%
import scipy.stats as stats

# %%
# observed value (x) 
# mean of the sample (µ)
# standard deviation of the sample (σ)
# standard score (Z) 
x = 3.17
µ = 5
σ = 1.5
Z = (x - µ)/σ

# %%
Z
# Out:
# -1.22

# %%
from scipy.stats import norm
x=np.linspace(-4,4,100)
plt.plot(x,norm.pdf(x,0,1))
plt.axvline(x=Z,c='r')
plt.title("Normal Distribution")
plt.xlabel("Breaking strength")
plt.ylabel("Probability")
plt.show()

# %%
stats.norm.cdf(-1.22)
# Out:
# 0.11123243744783456

# %% [markdown]
# ### 2.2 What proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm.?

# %%
# observed value (x) 
# mean of the sample (µ) 
# standard deviation of the sample (σ) 
# standard score (Z) 
x = 3.6
µ = 5
σ = 1.5
Z = (x - µ)/σ

# %%
Z
# Out:
# -0.9333333333333332

# %%
x=np.linspace(-4,4,100)
plt.plot(x,norm.pdf(x,0,1))
plt.axvline(x=Z,c='r')
plt.title("Normal Distribution")
plt.xlabel("Breaking strength")
plt.ylabel("Probability")
plt.show()

# %%
1-stats.norm.cdf(-0.933)
# Out:
# 0.8245900158241952

# %% [markdown]
# ### 2.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?

# %%
# observed value (x)
# mean of the sample (µ) 
# standard deviation of the sample (σ)
# standard score (Z1)
x = 5
µ = 5
σ = 1.5
Z1 = (x - µ)/σ

# %%
Z1
# Out:
# 0.0

# %%
# observed value (x) 
# mean of the sample (µ)
# standard deviation of the sample (σ) 
# standard score (Z2)
x = 5.5
µ = 5
σ = 1.5
Z2 = (x - µ)/σ

# %%
Z2
# Out:
# 0.3333333333333333

# %%
x=np.linspace(-4,4,100)
plt.plot(x,norm.pdf(x,0,1))
plt.axvline(x=Z1,c='r')
plt.axvline(x=Z2,c='r')
plt.title("Normal Distribution")
plt.xlabel("Breaking strength")
plt.ylabel("Probability")
plt.show()

# %%
stats.norm.cdf(Z2)-stats.norm.cdf(Z1)
# Out:
# 0.13055865981823633

# %% [markdown]
# ### 2.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %%
# observed value (x) 
# mean of the sample (µ) 
# standard deviation of the sample (σ) 
# standard score (Z1) 
x = 3
µ = 5
σ = 1.5
Z1 = (x - µ)/σ

# %%
Z1
# Out:
# -1.3333333333333333

# %%
# observed value (x)
# mean of the sample (µ) 
# standard deviation of the sample (σ)
# standard score (Z2)
x = 7.5
µ = 5
σ = 1.5
Z2 = (x - µ)/σ

# %%
Z2
# Out:
# 1.6666666666666667

# %%
x=np.linspace(-4,4,100)
plt.plot(x,norm.pdf(x,0,1))
plt.axvline(x=Z1,c='r')
plt.axvline(x=Z2,c='r')
plt.title("Normal Distribution")
plt.xlabel("Breaking strength")
plt.ylabel("Probability")
plt.show()

# %%
1-(stats.norm.cdf(Z2)-stats.norm.cdf(Z1))
# Out:
# 0.13900157199868257

# %% [markdown]
# # Problem 3

# %% [markdown]
# ## Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image, the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);

# %%
zf = pd.read_csv('D:\Downloads/Zingaro_Company.csv')

# %%
zf.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %%
zf.shape
# Out:
# (75, 2)

# %%
zf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unpolished            75 non-null     float64
#  1   Treated and Polished  75 non-null     float64
# dtypes: float64(2)
# memory usage: 1.3 KB

# %%
zf.describe().T
# Out:
#                       count        mean        std         min         25%  \
# Unpolished             75.0  134.110527  33.041804   48.406838  115.329753
# Treated and Polished   75.0  147.788117  15.587355  107.524167  138.268300
#
#                              50%         75%         max
# Unpolished            135.597121  158.215098  200.161313
# Treated and Polished  145.721322  157.373318  192.272856

# %% [markdown]
# ### 3.1 Zingaro has reason to believe that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?
# "- State the null and alternate hypotheses - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results Note: Consider the level of significance as 5%."

# %%
α = 0.05
x̄ = 134.11
s = 33.04
n = 75
df = 74

# %%
from scipy.stats import t, ttest_1samp
t_statistic, p_value = ttest_1samp(zf['Unpolished '],150)
print('One sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value/2))
# Out:
# One sample t test
# t statistic: -4.164629601426757 p value: 4.171286997419652e-05

# %%
critical_value = t.ppf(α, df)
print('critical_value:',critical_value)
# Out:
# critical_value: -1.665706892645352

# %% [markdown]
# ### 3.2 Is the mean hardness of the polished and unpolished stones the same?
# - State the null and alternate hypotheses. - Conduct the hypothesis test. - Write down conclusions from the test results. Note: Consider the level of significance as 5%.

# %%
Unpolished =zf['Unpolished '].mean()
Polished = zf['Treated and Polished'].mean()
print('The mean of Unpolished and Polished stones are:',Unpolished,Polished)
# Out:
# The mean of Unpolished and Polished stones are: 134.11052653373332 147.78811718133335

# %%
# Formulate the Null and Alternate Hypotheses
# Null hypothesis H0 : µ1 = µ2 (Mean hardness of the Polished and Unpolished are same)
# Alternate hypothesis HA : µ1 ≠ µ2 (Mean hardness of the Polished and Unpolished are not same)
print(zf.columns)
# Out:
# Index(['Unpolished ', 'Treated and Polished'], dtype='object')

# %%
from scipy.stats import   ttest_ind
t_statistic, p_value  = ttest_ind(zf['Treated and Polished'],zf['Unpolished '])
print('tstat=',t_statistic)    
print('P Value=',p_value)
# Out:
# tstat= 3.2422320501414053
# P Value= 0.0014655150194628353

# %% [markdown]
# # Problem 4

# %% [markdown]
# ## Dental implant data: The hardness of metal implants in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as the dentists who may favor one method above another and may work better in his/her favorite method. The response is the variable of interest.

# %%
df = pd.read_excel('D:\Downloads/Dental+Hardness+data.xlsx',sheet_name='Data')

# %%
df.head()
# Out:
#    Dentist  Method  Alloy  Temp  Response
# 0        1       1      1  1500       813
# 1        1       1      1  1600       792
# 2        1       1      1  1700       792
# 3        1       1      2  1500       907
# 4        1       1      2  1600       792

# %%
df.shape
# Out:
# (90, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
df.describe().T
# Out:
#           count         mean         std     min     25%     50%     75%  \
# Dentist    90.0     3.000000    1.422136     1.0     2.0     3.0     4.0
# Method     90.0     2.000000    0.821071     1.0     1.0     2.0     3.0
# Alloy      90.0     1.500000    0.502801     1.0     1.0     1.5     2.0
# Temp       90.0  1600.000000   82.107083  1500.0  1500.0  1600.0  1700.0
# Response   90.0   741.777778  145.767845   289.0   698.0   767.0   824.0
#
#              max
# Dentist      5.0
# Method       3.0
# Alloy        2.0
# Temp      1700.0
# Response  1115.0

# %% [markdown]
# ### 4.1 How does the hardness of implants vary depending on dentists?
# "- State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - In case the implant hardness differs, identify for which pairs it differs Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test."

# %%
# for alloy 1
df1=df[df['Alloy']==1]
# for alloy 2
df2=df[df['Alloy']==2]

# %%
df1.head()
# Out:
#    Dentist  Method  Alloy  Temp  Response
# 0        1       1      1  1500       813
# 1        1       1      1  1600       792
# 2        1       1      1  1700       792
# 6        1       2      1  1500       782
# 7        1       2      1  1600       698

# %%
df2.head()
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 3         1       1      2  1500       907
# 4         1       1      2  1600       792
# 5         1       1      2  1700       835
# 9         1       2      2  1500      1115
# 10        1       2      2  1600       835

# %%
sns.boxplot(x=df1['Response']);

# %%
sns.boxplot(x=df2['Response']);

# %%
df1.shape
# Out:
# (45, 5)

# %%
df2.shape
# Out:
# (45, 5)

# %%
df1.reset_index(drop=True)
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 0         1       1      1  1500       813
# 1         1       1      1  1600       792
# 2         1       1      1  1700       792
# 3         1       2      1  1500       782
# 4         1       2      1  1600       698
# 5         1       2      1  1700       665
# 6         1       3      1  1500       752
# 7         1       3      1  1600       620
# 8         1       3      1  1700       835
# 9         2       1      1  1500       715
# 10        2       1      1  1600       803
# 11        2       1      1  1700       813
# 12        2       2      1  1500       772
# 13        2       2      1  1600       782
# 14        2       2      1  1700       743
# 15        2       3      1  1500       835
# 16        2       3      1  1600       715
# 17        2       3      1  1700       673
# 18        3       1      1  1500       743
# 19        3       1      1  1600       627
# 20        3       1      1  1700       752
# ...

# %%
df2.reset_index(drop=True)
# Out:
#     Dentist  Method  Alloy  Temp  Response
# 0         1       1      2  1500       907
# 1         1       1      2  1600       792
# 2         1       1      2  1700       835
# 3         1       2      2  1500      1115
# 4         1       2      2  1600       835
# 5         1       2      2  1700       870
# 6         1       3      2  1500       847
# 7         1       3      2  1600       560
# 8         1       3      2  1700       585
# 9         2       1      2  1500       858
# 10        2       1      2  1600       907
# 11        2       1      2  1700       882
# 12        2       2      2  1500       933
# 13        2       2      2  1600       792
# 14        2       2      2  1700       824
# 15        2       3      2  1500       698
# 16        2       3      2  1600       734
# 17        2       3      2  1700       681
# 18        3       1      2  1500       858
# 19        3       1      2  1600       762
# 20        3       1      2  1700       724
# ...

# %%
from scipy.stats import anderson
result = anderson(df1['Response'],dist='norm')
print(f"Statistic: {result.statistic}")
print(f"Critical Values: {result.critical_values}")
print(f"Significance Levels: {result.significance_level}")
# Out:
# Statistic: 2.561066309273201
# Critical Values: [0.535 0.609 0.731 0.853 1.014]
# Significance Levels: [15.  10.   5.   2.5  1. ]

# %%
result2 = anderson(df1['Response'],dist='norm')
print(f"Statistic: {result2.statistic}")
print(f"Critical Values: {result2.critical_values}")
print(f"Significance Levels: {result2.significance_level}")
# Out:
# Statistic: 2.561066309273201
# Critical Values: [0.535 0.609 0.731 0.853 1.014]
# Significance Levels: [15.  10.   5.   2.5  1. ]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1['Dentist'] = pd.Categorical(df1['Dentist'])

# %%
df1['Dentist'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0     1
# 1     1
# 2     1
# 6     1
# 7     1
# 8     1
# 12    1
# 13    1
# 14    1
# 18    2
# 19    2
# 20    2
# 24    2
# 25    2
# 26    2
# 30    2
# 31    2
# 32    2
# 36    3
# 37    3
# 38    3
# 42    3
# 43    3
# 44    3
# 48    3
# 49    3
# 50    3
# 54    4
# 55    4
# 56    4
# 60    4
# 61    4
# 62    4
# 66    4
# 67    4
# 68    4
# 72    5
# 73    5
# 74    5
# 78    5
# 79    5
# 80    5
# 84    5
# 85    5
# 86    5
# Name: Dentist, dtype: category
# Categories (5, int64): [1, 2, 3, 4, 5]>

# %%
df2['Dentist'] = pd.Categorical(df2['Dentist'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 0 to 86
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   45 non-null     category
#  1   Method    45 non-null     int64
#  2   Alloy     45 non-null     int64
#  3   Temp      45 non-null     int64
#  4   Response  45 non-null     int64
# dtypes: category(1), int64(4)
# memory usage: 2.0 KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45 entries, 3 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   45 non-null     category
#  1   Method    45 non-null     int64
#  2   Alloy     45 non-null     int64
#  3   Temp      45 non-null     int64
#  4   Response  45 non-null     int64
# dtypes: category(1), int64(4)
# memory usage: 2.0 KB

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import _get_covariance,anova_lm

# %%
# for alloy 1
formula = 'Response ~ C(Dentist)'
model = ols(formula, df1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  1.977112  0.116567
# Residual    40.0  539593.555556  13489.838889       NaN       NaN

# %%
# for alloy 2
formula = 'Response ~ C(Dentist)'
model = ols(formula, df2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  5.679791e+04  14199.477778  0.524835  0.718031
# Residual    40.0  1.082205e+06  27055.122222       NaN       NaN

# %% [markdown]
# ### 4.2 How does the hardness of implants vary depending on methods?
# "- State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - In case the implant hardness differs, identify for which pairs it differs Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test."

# %%
df1['Method']= pd.Categorical(df1['Method'])
df2['Method']= pd.Categorical(df2['Method'])

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# %%
formula = 'Response ~ C(Method)'
model = ols(formula, df1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df         sum_sq       mean_sq         F    PR(>F)
# C(Method)   2.0  148472.177778  74236.088889  6.263327  0.004163
# Residual   42.0  497805.066667  11852.501587       NaN       NaN

# %%
mc=MultiComparison(df1['Response'],df1['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
sns.pointplot(x='Method', y='Response', data=df1, ci=None)
# Out:
# <Axes: xlabel='Method', ylabel='Response'>

# %%
formula = 'Response ~ C(Method)'
model = ols(formula, df2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#              df    sum_sq        mean_sq        F    PR(>F)
# C(Method)   2.0  499640.4  249820.200000  16.4108  0.000005
# Residual   42.0  639362.4   15222.914286      NaN       NaN

# %%
mc=MultiComparison(df2['Response'],df2['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %%
sns.pointplot(x='Method', y='Response', data=df, ci=None)
# Out:
# <Axes: xlabel='Method', ylabel='Response'>

# %% [markdown]
# ### 4.3 What is the interaction effect between the dentist and method on the hardness of dental implants for each type of alloy?
# "- Create Interaction Plot - Inferences from the plot Note: Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys."

# %%
formula = 'Response ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, df1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method):C(Dentist)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=df1, hue='Method', ci=None);

# %%
formula = 'Response ~ C(Method) + C(Dentist) + C(Method):C(Dentist)'
model = ols(formula, df2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method):C(Dentist)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=df2, hue='Method', ci=None);

# %% [markdown]
# ### 4.4 How does the hardness of implants vary depending on dentists and methods together?
# "- State the null and alternate hypotheses - Check the assumptions of the hypothesis test. - Conduct the hypothesis test and compute the p-value - Write down conclusions from the test results - Identify which dentists and methods combinations are different, and which interaction levels are different. Note: 1. Both types of alloys cannot be considered together. You must conduct the analysis separately for the two types of alloys. 2. Even if the assumptions of the test fail, kindly proceed with the test."

# %%
formula = 'Response ~ C(Method) + C(Dentist)'
model = ols(formula, df1).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %%
formula = 'Response ~ C(Method) + C(Dentist)'
model = ols(formula, df2).fit()
aov_table = anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %%
mc=MultiComparison(df1['Response'],df1['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#      1      2   -6.1333  0.987  -102.714  90.4473  False
#      1      3    -124.8 0.0085 -221.3807 -28.2193   True
#      2      3 -118.6667 0.0128 -215.2473  -22.086   True
# --------------------------------------------------------

# %%
sns.pointplot(x='Method', y='Response', data=df1, ci=None)
# Out:
# <Axes: xlabel='Method', ylabel='Response'>

# %%
mc=MultiComparison(df2['Response'],df2['Method'])
result=mc.tukeyhsd()
print(result)
# Out:
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj    lower     upper   reject
# --------------------------------------------------------
#      1      2     27.0 0.8212  -82.4546  136.4546  False
#      1      3   -208.8 0.0001 -318.2546  -99.3454   True
#      2      3   -235.8    0.0 -345.2546 -126.3454   True
# --------------------------------------------------------

# %%
sns.pointplot(x='Method', y='Response', data=df, ci=None)
# Out:
# <Axes: xlabel='Method', ylabel='Response'>
